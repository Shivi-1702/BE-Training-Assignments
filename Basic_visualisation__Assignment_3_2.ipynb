# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv("Iris.csv")

# %%
Data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Data.head(50)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(Data.index, Data['SepalLengthCm'], marker='o', linestyle='-', color='black')

# %%
plt.plot(Data['SepalLengthCm'],Data['PetalLengthCm'])

# %%
x = Data['SepalWidthCm']
y = Data['PetalWidthCm']

plt.plot(x, y, marker=',', linestyle='-', color='y')

plt.xlabel('SepalWidthCm')
plt.ylabel('PetalWidthCm')
plt.title('Species')
# Out:
# Text(0.5, 1.0, 'Species')

# %%
plt.scatter(Data ['SepalLengthCm'], Data ['SepalWidthCm'])

plt.xlabel("Sepal Width")
plt.ylabel('Sepal Length')
# Out:
# Text(0, 0.5, 'Sepal Length')

# %%
plt.scatter(x,y,marker = "*",color = "green")

# %%
  plt.scatter(Data['SepalLengthCm'],Data['SepalWidthCm'], alpha=0.7, edgecolor='pink')
  plt.title('Scatter Plot of Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-779fa0ada0fb>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Species')

# %%
plt.bar(Data['Species'], Data['PetalLengthCm'])
plt.grid()

# %%
plt.barh(Data ['Species'], Data ['PetalLengthCm'])
plt.xlabel('Petal Length (cm)')
plt.ylabel('Species')
plt.title('Petal Length by Species')
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %%
labels = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

sizes = [Data ['SepalLengthCm'].mean(), Data ['SepalWidthCm'].mean(), Data ['PetalLengthCm'].mean(), Data['PetalWidthCm'].mean()]
colors = ['red', 'green', 'yellow', 'blue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.f%%', startangle=140)

plt.title('pie chart')

plt.show()
