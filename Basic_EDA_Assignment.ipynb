# %%
import pandas as pd

# %%
df = pd.read_csv('car_price_dataset.csv')

# %%
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
# What are all the unique car brands (make) in the dataset?

df['Brand']
# Out:
# 0              Kia
# 1        Chevrolet
# 2         Mercedes
# 3             Audi
# 4       Volkswagen
#            ...
# 9995           Kia
# 9996     Chevrolet
# 9997           BMW
# 9998          Ford
# 9999    Volkswagen
# Name: Brand, Length: 10000, dtype: object

# %%
# What are the different types of fuel available?

df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Hybrid', 'Electric', 'Petrol'], dtype=object)

# %%
# Find all cars that use Diesel fuel.

df[df['Fuel_Type']=="Diesel"]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 15    Volkswagen      Golf  2007          3.2    Diesel       Automatic
# 18           Kia       Rio  2000          3.4    Diesel  Semi-Automatic
# 25           Kia  Sportage  2011          1.8    Diesel       Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9988         BMW  3 Series  2010          3.0    Diesel          Manual
# 9989      Toyota   Corolla  2003          1.6    Diesel  Semi-Automatic
# 9991    Mercedes   E-Class  2017          1.1    Diesel       Automatic
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
# What are the different types of transmission in the dataset?

df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic', 'Semi-Automatic'], dtype=object)

# %%
# Find all cars with automatic transmission.

df[df['Transmission']=="Automatic"]
# Out:
#           Brand     Model  Year  Engine_Size Fuel_Type Transmission  Mileage  \
# 1     Chevrolet    Malibu  2012          2.0    Hybrid    Automatic     5356
# 2      Mercedes       GLA  2020          4.2    Diesel    Automatic   231440
# 5        Toyota     Camry  2007          2.7    Petrol    Automatic   157889
# 6         Honda     Civic  2010          3.4  Electric    Automatic   139584
# 10          BMW  5 Series  2013          1.3    Hybrid    Automatic   296824
# ...         ...       ...   ...          ...       ...          ...      ...
# 9991   Mercedes   E-Class  2017          1.1    Diesel    Automatic   179286
# 9992        BMW  5 Series  2016          1.2    Hybrid    Automatic    13386
# 9996  Chevrolet    Impala  2002          1.4  Electric    Automatic   168000
# 9997        BMW  3 Series  2010          3.0    Petrol    Automatic    86664
# 9998       Ford  Explorer  2002          1.4    Hybrid    Automatic   225772
#
#       Doors  Owner_Count  Price
# ...

# %%
# Find all cars manufactured in the year 2015

df[df['Year']=="2015"]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Year, Engine_Size, Fuel_Type, Transmission, Mileage, Doors, Owner_Count, Price]
# Index: []

# %%
# Find all cars priced less than $10,000.

df[df['Price']<10000]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 5         Toyota     Camry  2007          2.7    Petrol       Automatic
# 7            Kia  Sportage  2001          4.7  Electric  Semi-Automatic
# 8            Kia  Sportage  2014          2.6    Hybrid          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
# Find all cars that have driven less than 50,000 kilometers (or miles).

df[df['Mileage']<50000]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 11    Volkswagen      Golf  2009          4.5    Hybrid          Manual
# 16       Hyundai   Elantra  2017          2.9  Electric       Automatic
# 17    Volkswagen    Tiguan  2006          4.5  Electric          Manual
# 19      Mercedes       GLA  2021          1.5    Petrol          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9974    Mercedes   C-Class  2020          1.1    Diesel          Manual
# 9980       Honda      CR-V  2012          1.5    Petrol          Manual
# 9987         BMW  5 Series  2004          1.3    Diesel          Manual
# 9992         BMW  5 Series  2016          1.2    Hybrid       Automatic
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 1        5356      2            3  12092
# ...

# %%
# Find all cars that are of body type 'SUV'

df[df['Fuel_Type']=="SUV"]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Year, Engine_Size, Fuel_Type, Transmission, Mileage, Doors, Owner_Count, Price]
# Index: []

# %%
import pandas as pd

# %%
data = pd.read_csv('disney_princess_popularity_dataset_300_rows.csv')

# %%
data
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 1          Mulan       Mulan's Adventure            1995                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# ..           ...                     ...             ...                  ...
# 295       Merida      Merida's Adventure            2001                   95
# 296        Belle       Belle's Adventure            2006                   76
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
# List all the unique hair colors of the princesses.
data['HairColor'].unique()
# Out:
# array(['Brown', 'Blonde', 'White', 'Black', 'Red'], dtype=object)

# %%
# Find all princesses with black hair.
data[data['HairColor']=="Black"]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 7       Rapunzel    Rapunzel's Adventure            1987                   79
# 9           Anna        Anna's Adventure            2010                  108
# 24         Tiana       Tiana's Adventure            2019                  108
# 29         Mulan       Mulan's Adventure            1983                   70
# 35          Raya        Raya's Adventure            2007                   87
# 40        Merida      Merida's Adventure            1993                   74
# 41      Rapunzel    Rapunzel's Adventure            1977                   70
# 53         Tiana       Tiana's Adventure            1991                   71
# 58         Belle       Belle's Adventure            1937                  105
# 59          Anna        Anna's Adventure            1991                  105
# 85        Aurora      Aurora's Adventure            1952                   75
# ...

# %%
# List all the unique eye colors of the princesses.
data['EyeColor'].unique()
# Out:
# array(['Green', 'Brown', 'Hazel', 'Grey', 'Blue'], dtype=object)

# %%
# Find all princesses who have blue eyes.

data[data['EyeColor']=="Blue"]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 5        Jasmine     Jasmine's Adventure            2010                   78
# 6     Snow White  Snow White's Adventure            1986                   97
# 20        Aurora      Aurora's Adventure            1977                   72
# 30       Jasmine     Jasmine's Adventure            1996                   82
# 33          Raya        Raya's Adventure            1997                  104
# ..           ...                     ...             ...                  ...
# 280       Aurora      Aurora's Adventure            1972                   95
# 286   Snow White  Snow White's Adventure            2005                   96
# 292         Anna        Anna's Adventure            1956                   95
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
#
# ...

# %%
# Find all princesses whose movies were released before 1990
data[data['FirstMovieYear']<1990]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# 6     Snow White  Snow White's Adventure            1986                   97
# ..           ...                     ...             ...                  ...
# 291   Cinderella  Cinderella's Adventure            1964                   82
# 292         Anna        Anna's Adventure            1956                   95
# 293        Moana       Moana's Adventure            1961                   96
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
# Find all princesses who have an animal sidekick.

# %%
# List all the unique movies the princesses appear in
data['FirstMovieTitle'].unique()
# Out:
# array(["Pocahontas's Adventure", "Mulan's Adventure", "Raya's Adventure",
#        "Anna's Adventure", "Jasmine's Adventure",
#        "Snow White's Adventure", "Rapunzel's Adventure",
#        "Belle's Adventure", "Cinderella's Adventure", "Ariel's Adventure",
#        "Elsa's Adventure", "Aurora's Adventure", "Moana's Adventure",
#        "Tiana's Adventure", "Merida's Adventure"], dtype=object)

# %%
# Find all princesses whose movie was released after 2010.
data[data['PrincessName']<'2010']
# Out:
# Empty DataFrame
# Columns: [PrincessName, FirstMovieTitle, FirstMovieYear, MovieRuntimeMinutes, NumberOfSongs, HasSoloSong, HasDuet, HairColor, EyeColor, OutfitPrimaryColor, OutfitStyleEra, IsRoyalByBirth, HasAnimalSidekick, SidekickType, HasMagicalPowers, MagicType, MainSetting, IsBasedOnRealStory, CulturalOrigin, SpeaksToAnimals, FightsVillainDirectly, RomanticSubplot, MarriedByEnd, VillainName, VillainType, IMDB_Rating, RottenTomatoesScore, BoxOfficeMillions, AvgScreenTimeMinutes, NumMerchItemsOnAmazon, GoogleSearchIndex2024, InstagramFanPages, TikTokHashtagViewsMillions, Top3Hashtags, IsIconic, PopularityScore]
# Index: []
#
# [0 rows x 36 columns]

# %%
# Find all princesses who are older than 18 years old.
data[data['PrincessName']>'18']
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 1          Mulan       Mulan's Adventure            1995                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# ..           ...                     ...             ...                  ...
# 295       Merida      Merida's Adventure            2001                   95
# 296        Belle       Belle's Adventure            2006                   76
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
# Find all princesses who sing more than 3 songs.
data[data['NumberOfSongs']>3]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 2           Raya        Raya's Adventure            1989                  110
# 4          Mulan       Mulan's Adventure            1943                  103
# 5        Jasmine     Jasmine's Adventure            2010                   78
# 8           Anna        Anna's Adventure            2007                   94
# ..           ...                     ...             ...                  ...
# 289       Merida      Merida's Adventure            1953                   83
# 293        Moana       Moana's Adventure            1961                   96
# 294   Pocahontas  Pocahontas's Adventure            2019                   95
# 295       Merida      Merida's Adventure            2001                   95
# 298        Tiana       Tiana's Adventure            1937                   71
#
# ...
